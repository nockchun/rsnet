# %% [markdown]
# # Configure Learning Environment

# %%
#!pip install git+https://github.com/nockchun/rspy --force
import rspy as rsp
rsp.setSystemWarning(off=True)

# %%
#!pip install OpenDartReader

# %%
import OpenDartReader
from bs4 import BeautifulSoup
import pandas as pd

# %%
api_key = '125e216fefd7c214a1a66784b73f76075dff77b7'
dart = OpenDartReader(api_key)

# %% [markdown]
# # find_corp_code() - 고유번호 얻기

# %%
dart.find_corp_code("053800"), dart.find_corp_code("안랩")
# Out:
# ('00298270', '00298270')

# %% [markdown]
# # list() - 공시검색
# * `kind` (문자열, 기본값=''): 공시유형 ('A'=정기공시, 'B'=주요사항보고, 'C'=발행공시, 'D'=지분공시, 'E'=기타공시, 'F'=외부감사관련, 'G'=펀드공시, 'H'=자산유동화, 'I'=거래소공시, 'J'=공정위공시)
# * `kind_detail` (문자열, 기본값=''): 공시 상세 유형. ('5'=정기공시, '3'=주요사항보고, '11'=발행공시, '4'=지분공시, '9'=기타공시, '5'=외부감사관련, '3'=펀드공시, '6'=자산유동화, '6'=거래소공시, '5'=공정위공시)

# %%
dart.list('053800', kind='I', start='2020-01-01', end='2020-12-31')
# Out:
#    corp_code corp_name stock_code corp_cls  \
# 0   00298270        안랩     053800        K
# 1   00298270        안랩     053800        K
# 2   00298270        안랩     053800        K
# 3   00298270        안랩     053800        K
# 4   00298270        안랩     053800        K
# 5   00298270        안랩     053800        K
# 6   00298270        안랩     053800        K
# 7   00298270        안랩     053800        K
# 8   00298270        안랩     053800        K
# 9   00298270        안랩     053800        K
# 10  00298270        안랩     053800        K
# 11  00298270        안랩     053800        K
# 12  00298270        안랩     053800        K
#
#                               report_nm        rcept_no flr_nm  rcept_dt rm
# 0                연결재무제표기준영업(잠정)실적(공정공시)  20200429900170     안랩  20200429  코
# 1                        영업(잠정)실적(공정공시)  20200429900169     안랩  20200429  코
# 2                              결산실적공시예고  20200423900601     안랩  20200423  코
# 3                                대표이사변경  20200327900397     안랩  20200327  코
# 4                              정기주주총회결과  20200327900375     안랩  20200327  코
# 5                               감사보고서제출  20200318901478     안랩  20200318  코
# 6                         주주총회집중일개최사유신고  20200311900828     안랩  20200311  코
# 7                             현금ㆍ현물배당결정  20200211900116     안랩  20200211  코
# 8                              주주총회소집결의  20200211900114     안랩  20200211  코
# 9                연결재무제표기준영업(잠정)실적(공정공시)  20200211900111     안랩  20200211  코
# 10                       영업(잠정)실적(공정공시)  20200211900110     안랩  20200211  코
# 11                             결산실적공시예고  20200205900835     안랩  20200205  코
# 12  수시공시의무관련사항(공정공시)(대표이사 변경 예정에 관한 사항)  20200102900085     안랩  20200102  코

# %% [markdown]
# # document() - 공시서류 원문
# * 공시보고서 접수번호(rcp_no)에 해당하는 공시보고서 원본 문서를 XML문서로 반환합니다

# %%
xml_text = dart.document('20200327900375') # 사업보고서 (2018.12)
xml_text[:2000]
# Out:
# '\r\n<html>\r\n <head>\r\n  <META content="gdi" http-equiv="X-UA-TextLayoutMetrics"/>\r\n  <meta content="text/html; charset=euc-kr" http-equiv="Content-Type"/>\r\n  <STYLE>\r\n.xforms * { font-family: 돋움체;}\r\n.xforms_title * { font-size: 13pt; padding : 0 0 10 0;}\r\n\r\n.xforms table {\r\n    font-size: 10px;\r\n    padding:0px;\r\n    border-collapse:collapse;\r\n    color: #3D3D3D;\r\n}\r\n.xforms td {\r\n    padding-left:0px;\r\n    padding-top:0px;\r\n    border-collapse:collapse;\r\n    line-height:22px;\r\n    color: #3D3D3D;\r\n    /*text-align:right;*/\r\n    vertical-align:middle;\r\n    border: 1px solid #7f7f7f;\r\n}\r\n\r\n.xforms span {\r\n    /*display: inline-block;*/\r\n    padding-left:3px;\r\n    padding-right: 1px;\r\n    line-height:22px;\r\n    padding-top:0px;\r\n    padding-bottom:0px;\r\n    text-align:left;\r\n    vertical-align:middle;\r\n    border: 0px solid #DBDBDB;\r\n}\r\n\r\n.xforms.img{\r\n    border : 0px;\r\n}\r\n\r\n.xforms a:link {\r\n\r\n    color: #194866;\r\n    text-decoration: none;\r\n}\r\n.xforms a:active {\r\n\r\n    color: #194866;\r\n    text-decoration: none;\r\n}\r\n.xforms a:visited {\r\n    color: #194866;\r\n    text-decoration: none;\r\n}\r\n\r\n.xforms A:hover {\r\n    color:008BE3;\r\n    text-decoration: none;\r\n}\r\n\r\n.xforms_input{\r\n    border: 0px solid #DBDBDB;\r\n    padding-left:3px;\r\n    padding-right: 1px;\r\n    height:22px;\r\n    padding-top:0px;\r\n    padding-bottom:0px;\r\n    text-align:left;\r\n}\r\n</STYLE>\r\n  <title>안랩/정기주주총회결과/(2020.03.27)정기주주총회결과</title>\r\n </head>\r\n <body>\r\n  <div class="xforms">\r\n   <div>\r\n    <span class="noprint" style="display:none;width:600px;font-size:10pt;">\r\n    </span>\r\n    <div class="xforms_title">\r\n     <div>\r\n      <span style="width:592px;font-weight:bold;text-align:center;">정기주주총회 결과</span>\r\n     </div>\r\n    </div>\r\n    <table border="1" borderColorDark="white" borderColorLight="#666666" cellpadding="1" cellspacing="0" id="XFormD1_Form0_Table0" style="margin:0px 0px 20px 0px;width:600px;font-size:10pt;border:1px solid #7f7f7f;">\r\n     <tbody>\r\n      <tr>\r\n       <td colspan="6" width="600">'

# %%
soup = BeautifulSoup(xml_text, "html.parser")

# %%
document = soup.get_text()

# %%
document.replace("\n", "").replace("\r", "")
# Out:
# '안랩/정기주주총회결과/(2020.03.27)정기주주총회결과정기주주총회 결과1. 재무제표 승인ㆍ보고제 25기(단위 : 백만원)가. 개별(별도)- 자산총계256,805- 매출액163,005- 부채총계52,540- 영업이익18,036- 자본금5,183- 당기순이익18,947- 자본총계204,265*주당순이익(원)2,181나. 연결- 자산총계260,217- 매출액166,992- 부채총계54,545- 영업이익18,424- 자본금5,183- 당기순이익19,142- 자본총계205,672*주당순이익(원)2,204* 회계감사인 감사의견개별(별도)적정연결적정2. 배당 결의ㆍ보고가. 현금ㆍ현물 배당배당종류현금배당- 현물자산의 상세내역-1주당 배당금(원)보통주식기말배당금900중간ㆍ분기배당금-종류주식기말배당금-중간ㆍ분기배당금-배당금총액(원)7,817,204,700시가배당율(%)(중간배당 포함)보통주식1.4종류주식-나. 주식배당주식배당률 (%)보통주식-종류주식-배당주식총수 (주)보통주식-종류주식-3. 임원 현황 (선임일 현재)가. 임원선임 현황상근이사 1인나. 선임후 사외이사수(명)이사총수5사외이사총수3사외이사선임비율(%)60다. 선임후 감사수(명)상근감사 수-비상근감사 수-라. 선임후 감사위원수(명)사외이사인 감사위원3사외이사가 아닌 감사위원 수-4. 기타 결의사항제1호 의안 : 제25기(2019.1.1~12.31) 재무제표 승인의 건         \xa0\xa0 \xa0 \xa0 \xa0 \xa0 \xa0-> 원안대로 가결         -제2호 의안 : 이사 선임의 건         \xa0\xa0 \xa0 \xa0 \xa0 \xa0 \xa0-> 원안대로 가결         \xa0\xa0         -제3호 의안 : 이사보수한도 승인의 건         \xa0\xa0 \xa0 \xa0 \xa0 \xa0 \xa0-> 원안대로 가결5. 주주총회일자2020-03-276. 기타 투자판단에 참고할 사항-※관련공시2020-03-11 주주총회소집공고2020-02-11 주주총회소집결의이사선임 세부내역성명출생년월임기신규선임여부주요경력(현직포함)강석균1960-093신규선임現)안랩 CEO            -액센츄어 사업총괄            -다이멘션데이터 사업총괄            -인포매티카 한국법인 지사장            -코오롱베니트 솔루션사업 영업총괄            -한국IBM 스토리지사업본부장'

# %% [markdown]
# # report() - 사업보고서 주요정보
# * key_word (문자열): 조회 내용 지정, 아래 "key_word 항목"을 참고하십시오 ('증자','배당','자기주식','최대주주','최대주주변동','소액주주','임원','직원','임원개인보수','임원전체보수','개인별보수','타법인출자')

# %%
dart.report('00298270', '직원', 2019)
# Out:
#          rcept_no corp_cls corp_code corp_name rm sexdstn fo_bbm  \
# 0  20200330003115        K  00298270        안랩  -       남     본사
# 1  20200330003115        K  00298270        안랩  -       여     본사
#
#   reform_bfe_emp_co_rgllbr reform_bfe_emp_co_cnttk reform_bfe_emp_co_etc  \
# 0                        -                       -                     -
# 1                        -                       -                     -
#
#   rgllbr_co rgllbr_abacpt_labrr_co cnttk_co cnttk_abacpt_labrr_co   sm  \
# 0       968                      0        7                     0  975
# 1       208                      0        4                     0  212
#
#   avrg_cnwk_sdytrn fyer_salary_totamt jan_salary_am
# 0             6.06     52,439,945,000    53,852,000
# 1             5.20      9,269,783,000    44,344,000

# %% [markdown]
# # finstate() - 재무 정보
# * reprt_code (문자열): 보고서 코드 ('11013'=1분기보고서, '11012'=반기보고서, '11014'=3분기보고서, '11011'=사업보고서)

# %% [markdown]
# * rcept_no: 접수번호
# * corp_code: 사업 연도
# * stock_code: 종목 코드
# * reprt_code: 보고서 코드
# * account_nm: 계정명 (예: 자본총계)
# * fs_div: 개별/연결구분 ('CFS'=연결재무제표, 'OFS'=재무제표)
# * fs_nm: 개별/연결명 ('연결재무제표' 또는 '재무제표')
# * sj_div: 재무제표구분 ('BS'=재무상태표, 'IS'=손익계산서)
# * sj_nm: 재무제표명 ( '재무상태표' 또는 '손익계산서')
# * thstrm_nm: 당기명
# * thstrm_dt: 당기일자
# * thstrm_amount: 당기금액
# * thstrm_add_amount: 당기누적금액
# * frmtrm_nm: 전기명
# * frmtrm_dt: 전기일자
# * frmtrm_amount: 전기금액
# * frmtrm_add_amount: 전기누적금액
# * bfefrmtrm_nm: 전전기명
# * bfefrmtrm_dt: 전전일자
# * bfefrmtrm_amount: 전전기금액
# * ord: 계정과목 정렬순서

# %%
fsdf = dart.finstate_all('안랩', '2020', reprt_code='11013')[
    ["sj_nm", "account_nm", "account_detail", "thstrm_nm", "thstrm_amount", "frmtrm_nm", "frmtrm_amount", "ord"]
]

# %%
fsdf.rename(columns={
    "sj_nm":"재무제표명", "account_nm":"계정명", "account_detail":"상세계정명", 
    "thstrm_nm":"당기명", "thstrm_amount":"당기금액", "frmtrm_nm":"전기명", "frmtrm_amount":"전기금액"
}, inplace=True)

# %%
fsdf.rename({"sj_nm":"재무제표명"}, inplace=True)
fsdf.재무제표명.unique()
# Out:
# array(['재무상태표', '포괄손익계산서', '현금흐름표', '자본변동표'], dtype=object)

# %%
fsdf[fsdf["재무제표명"]=="재무상태표"]
# Out:
#     재무제표명                         계정명 상세계정명          당기명          당기금액  \
# 0   재무상태표                        유동자산     -  제 26 기 1분기말  175964571597
# 1   재무상태표                    현금및현금성자산     -  제 26 기 1분기말   22086304514
# 2   재무상태표                       정부보조금     -  제 26 기 1분기말     130000000
# 3   재무상태표               매출채권 및 기타유동채권     -  제 26 기 1분기말   23291940874
# 4   재무상태표                        재고자산     -  제 26 기 1분기말    3146704678
# 5   재무상태표                    기타유동금융자산     -  제 26 기 1분기말  123292901314
# 6   재무상태표                      기타유동자산     -  제 26 기 1분기말    4276720217
# 7   재무상태표                       비유동자산     -  제 26 기 1분기말   90842307603
# 8   재무상태표                        유형자산     -  제 26 기 1분기말   53695261379
# 9   재무상태표                       사용권자산     -  제 26 기 1분기말     308154484
# 10  재무상태표                       투자부동산     -  제 26 기 1분기말    6238235375
# 11  재무상태표                         영업권     -  제 26 기 1분기말    3019258971
# 12  재무상태표                영업권 이외의 무형자산     -  제 26 기 1분기말    3754222276
# 13  재무상태표                   기타비유동금융자산     -  제 26 기 1분기말   20718591223
# 14  재무상태표  종속기업, 조인트벤처와 관계기업에 대한 투자자산     -  제 26 기 1분기말     352500000
# 15  재무상태표                     이연법인세자산     -  제 26 기 1분기말    2756083895
# 16  재무상태표                        자산총계     -  제 26 기 1분기말  266806879200
# 17  재무상태표                        유동부채     -  제 26 기 1분기말   60185313049
# 18  재무상태표               매입채무 및 기타유동채무     -  제 26 기 1분기말   14596429891
# 19  재무상태표                      유동리스부채     -  제 26 기 1분기말     259750062
# 20  재무상태표                     당기법인세부채     -  제 26 기 1분기말    1906105561
# 21  재무상태표                      기타유동부채     -  제 26 기 1분기말   43423027535
# 22  재무상태표                       비유동부채     -  제 26 기 1분기말    4561072476
# 23  재무상태표                       장기차입금     -  제 26 기 1분기말     200000000
# 24  재무상태표                     비유동리스부채     -  제 26 기 1분기말      52197666
# 25  재무상태표                   기타비유동금융부채     -  제 26 기 1분기말     710687000
# 26  재무상태표                      퇴직급여부채     -  제 26 기 1분기말     388285038
# 27  재무상태표                     이연법인세부채     -  제 26 기 1분기말      54252127
# 28  재무상태표                     기타비유동부채     -  제 26 기 1분기말    3155650645
# 29  재무상태표                        부채총계     -  제 26 기 1분기말   64746385525
# 30  재무상태표         지배기업의 소유주에게 귀속되는 자본     -  제 26 기 1분기말  201273133446
# 31  재무상태표                         자본금     -  제 26 기 1분기말    5182644500
# 32  재무상태표                       자본잉여금     -  제 26 기 1분기말   68207332465
# 33  재무상태표                    기타자본구성요소     -  제 26 기 1분기말  -21151879846
# 34  재무상태표                   기타포괄손익누계액     -  제 26 기 1분기말    -359251402
# 35  재무상태표                  이익잉여금(결손금)     -  제 26 기 1분기말  149394287729
# 36  재무상태표                       비지배지분     -  제 26 기 1분기말     787360229
# 37  재무상태표                        자본총계     -  제 26 기 1분기말  202060493675
# 38  재무상태표                     자본과부채총계     -  제 26 기 1분기말  266806879200
#
#         전기명          전기금액 ord
# 0   제 25 기말  168697109400   1
# 1   제 25 기말   24436824975   2
# 2   제 25 기말      60000000   3
# 3   제 25 기말   25468624343   4
# 4   제 25 기말    2557451714   5
# 5   제 25 기말  112076575569   6
# 6   제 25 기말    4217632799   7
# 7   제 25 기말   91519694580   8
# 8   제 25 기말   54580277228   9
# 9   제 25 기말     372363142  10
# 10  제 25 기말    6272985502  11
# 11  제 25 기말             0  12
# 12  제 25 기말    3620361039  13
# 13  제 25 기말   23565123774  14
# 14  제 25 기말     352500000  15
# 15  제 25 기말    2756083895  16
# 16  제 25 기말  260216803980  17
# 17  제 25 기말   50966673645  19
# 18  제 25 기말   17083880337  20
# 19  제 25 기말     268252050  21
# 20  제 25 기말    2644627106  22
# 21  제 25 기말   30969914152  23
# 22  제 25 기말    3578131067  24
# 23  제 25 기말             0  25
# 24  제 25 기말     107729559  26
# 25  제 25 기말     684931700  27
# 26  제 25 기말     311989391  28
# 27  제 25 기말             0  29
# 28  제 25 기말    2473480417  30
# 29  제 25 기말   54544804712  31
# 30  제 25 기말  205671999268  33
# 31  제 25 기말    5182644500  34
# 32  제 25 기말   68207332465  35
# 33  제 25 기말  -21151879846  36
# 34  제 25 기말    -372462030  37
# 35  제 25 기말  153806364179  38
# 36  제 25 기말             0  39
# 37  제 25 기말  205671999268  40
# 38  제 25 기말  260216803980  41

# %%
fsdf[fsdf["재무제표명"]=="손익계산서"]
# Out:
# Empty DataFrame
# Columns: [재무제표명, 계정명, 상세계정명, 당기명, 당기금액, 전기명, 전기금액, ord]
# Index: []

# %%
fsdf[fsdf["재무제표명"]=="포괄손익계산서"]
# Out:
#       재무제표명                            계정명 상세계정명         당기명         당기금액  \
# 39  포괄손익계산서                        수익(매출액)     -  제 26 기 1분기  40408972912
# 40  포괄손익계산서                           매출원가     -  제 26 기 1분기   7724563663
# 41  포괄손익계산서                          매출총이익     -  제 26 기 1분기  32684409249
# 42  포괄손익계산서                        판매비와관리비     -  제 26 기 1분기  29731614247
# 43  포괄손익계산서                       영업이익(손실)     -  제 26 기 1분기   2952795002
# 44  포괄손익계산서                           기타이익     -  제 26 기 1분기    371918494
# 45  포괄손익계산서                           기타손실     -  제 26 기 1분기    126110892
# 46  포괄손익계산서                           금융수익     -  제 26 기 1분기    959318395
# 47  포괄손익계산서                           금융원가     -  제 26 기 1분기    418872527
# 48  포괄손익계산서                법인세비용차감전순이익(손실)     -  제 26 기 1분기   3739048472
# 49  포괄손익계산서                          법인세비용     -  제 26 기 1분기    467054013
# 50  포괄손익계산서                      당기순이익(손실)     -  제 26 기 1분기   3271994459
# 51  포괄손익계산서                         기타포괄손익     -  제 26 기 1분기     13210628
# 52  포괄손익계산서    당기손익으로 재분류되지 않는항목(세후기타포괄손익)     -  제 26 기 1분기            0
# 53  포괄손익계산서        확정급여제도의 재측정손익(세후기타포괄손익)     -  제 26 기 1분기            0
# 54  포괄손익계산서  당기손익으로 재분류될 수 있는 항목(세후기타포괄손익)     -  제 26 기 1분기     13210628
# 55  포괄손익계산서          해외사업장환산외환차이(세후기타포괄손익)     -  제 26 기 1분기     13210628
# 56  포괄손익계산서                          총포괄손익     -  제 26 기 1분기   3285205087
# 57  포괄손익계산서     지배기업의 소유주에게 귀속되는 당기순이익(손실)     -  제 26 기 1분기   3405128250
# 58  포괄손익계산서          비지배지분에 귀속되는 당기순이익(손실)     -  제 26 기 1분기   -133133791
# 59  포괄손익계산서    총 포괄손익, 지배기업의 소유주에게 귀속되는 지분     -  제 26 기 1분기   3418338878
# 60  포괄손익계산서                  총 포괄손익, 비지배지분     -  제 26 기 1분기   -133133791
# 61  포괄손익계산서                     기본주당이익(손실)     -  제 26 기 1분기          377
# 62  포괄손익계산서                     희석주당이익(손실)     -  제 26 기 1분기          377
#
#     전기명 전기금액 ord
# 39  NaN  NaN   0
# 40  NaN  NaN   1
# 41  NaN  NaN   2
# 42  NaN  NaN   3
# 43  NaN  NaN   4
# 44  NaN  NaN   5
# 45  NaN  NaN   6
# 46  NaN  NaN   7
# 47  NaN  NaN   8
# 48  NaN  NaN   9
# 49  NaN  NaN  10
# 50  NaN  NaN  11
# 51  NaN  NaN  12
# 52  NaN  NaN  13
# 53  NaN  NaN  14
# 54  NaN  NaN  15
# 55  NaN  NaN  16
# 56  NaN  NaN  17
# 57  NaN  NaN  19
# 58  NaN  NaN  20
# 59  NaN  NaN  22
# 60  NaN  NaN  23
# 61  NaN  NaN  25
# 62  NaN  NaN  26

# %%
fsdf[fsdf["재무제표명"]=="현금흐름표"]
# Out:
#     재무제표명                             계정명 상세계정명         당기명          당기금액  \
# 63  현금흐름표                        영업활동현금흐름     -  제 26 기 1분기    8460190956
# 64  현금흐름표                   영업으로부터 창출된 현금     -  제 26 기 1분기    8857175553
# 65  현금흐름표                        이자수취(영업)     -  제 26 기 1분기     799719385
# 66  현금흐름표                       배당금수취(영업)     -  제 26 기 1분기       5787513
# 67  현금흐름표                       법인세납부(환급)     -  제 26 기 1분기    1202491495
# 68  현금흐름표                        투자활동현금흐름     -  제 26 기 1분기  -10932245346
# 69  현금흐름표                        유형자산의 처분     -  제 26 기 1분기        670000
# 70  현금흐름표                    기타유동금융자산의 처분     -  제 26 기 1분기    7575301469
# 71  현금흐름표                   기타비유동금융자산의 처분     -  제 26 기 1분기     477450000
# 72  현금흐름표                        유형자산의 취득     -  제 26 기 1분기     758315672
# 73  현금흐름표                        무형자산의 취득     -  제 26 기 1분기     211703665
# 74  현금흐름표                    기타유동금융자산의 취득     -  제 26 기 1분기   11200000000
# 75  현금흐름표                   기타비유동금융자산의 취득     -  제 26 기 1분기    5231078959
# 76  현금흐름표  종속기업, 조인트벤처와 관계기업에 대한 투자자산의 취득     -  제 26 기 1분기             0
# 77  현금흐름표                         연결범위 변동     -  제 26 기 1분기   -1584568519
# 78  현금흐름표                        재무활동현금흐름     -  제 26 기 1분기     -85859708
# 79  현금흐름표                           배당금지급     -  제 26 기 1분기             0
# 80  현금흐름표                        리스부채의 상환     -  제 26 기 1분기      85859708
# 81  현금흐름표    환율변동효과 반영전 현금및현금성자산의 순증가(감소)     -  제 26 기 1분기   -2557914098
# 82  현금흐름표             현금및현금성자산에 대한 환율변동효과     -  제 26 기 1분기     207393637
# 83  현금흐름표                현금및현금성자산의순증가(감소)     -  제 26 기 1분기   -2350520461
# 84  현금흐름표                      기초현금및현금성자산     -  제 26 기 1분기   24436824975
# 85  현금흐름표                      기말현금및현금성자산     -  제 26 기 1분기   22086304514
#
#     전기명 전기금액 ord
# 63  NaN  NaN   0
# 64  NaN  NaN   1
# 65  NaN  NaN   2
# 66  NaN  NaN   3
# 67  NaN  NaN   4
# 68  NaN  NaN   5
# 69  NaN  NaN   6
# 70  NaN  NaN   7
# 71  NaN  NaN   8
# 72  NaN  NaN   9
# 73  NaN  NaN  10
# 74  NaN  NaN  11
# 75  NaN  NaN  12
# 76  NaN  NaN  13
# 77  NaN  NaN  14
# 78  NaN  NaN  15
# 79  NaN  NaN  16
# 80  NaN  NaN  17
# 81  NaN  NaN  18
# 82  NaN  NaN  19
# 83  NaN  NaN  20
# 84  NaN  NaN  21
# 85  NaN  NaN  22

# %%
fsdf[fsdf["재무제표명"]=="자본변동표"]
# Out:
#      재무제표명         계정명                                              상세계정명  \
# 86   자본변동표        기초자본                                    연결재무제표 [member]
# 87   자본변동표        기초자본           자본 [member]|지배기업의 소유주에게 귀속되는 자본 [member]
# 88   자본변동표        기초자본  자본 [member]|지배기업의 소유주에게 귀속되는 자본 [member]|기타자본구...
# 89   자본변동표        기초자본  자본 [member]|지배기업의 소유주에게 귀속되는 자본 [member]|기타포괄손...
# 90   자본변동표        기초자본  자본 [member]|지배기업의 소유주에게 귀속되는 자본 [member]|이익잉여금...
# 91   자본변동표        기초자본  자본 [member]|지배기업의 소유주에게 귀속되는 자본 [member]|자본금 [...
# 92   자본변동표        기초자본  자본 [member]|지배기업의 소유주에게 귀속되는 자본 [member]|자본잉여금...
# 93   자본변동표  연결대상범위의 변동                                    연결재무제표 [member]
# 94   자본변동표  연결대상범위의 변동                         자본 [member]|비지배지분 [member]
# 95   자본변동표   당기순이익(손실)                                    연결재무제표 [member]
# 96   자본변동표   당기순이익(손실)                         자본 [member]|비지배지분 [member]
# 97   자본변동표   당기순이익(손실)           자본 [member]|지배기업의 소유주에게 귀속되는 자본 [member]
# 98   자본변동표   당기순이익(손실)  자본 [member]|지배기업의 소유주에게 귀속되는 자본 [member]|이익잉여금...
# 99   자본변동표      기타포괄손익                                    연결재무제표 [member]
# 100  자본변동표      기타포괄손익           자본 [member]|지배기업의 소유주에게 귀속되는 자본 [member]
# 101  자본변동표      기타포괄손익  자본 [member]|지배기업의 소유주에게 귀속되는 자본 [member]|기타포괄손...
# 102  자본변동표       배당금지급                                    연결재무제표 [member]
# 103  자본변동표       배당금지급           자본 [member]|지배기업의 소유주에게 귀속되는 자본 [member]
# 104  자본변동표       배당금지급  자본 [member]|지배기업의 소유주에게 귀속되는 자본 [member]|이익잉여금...
# 105  자본변동표        기말자본                                    연결재무제표 [member]
# 106  자본변동표        기말자본                         자본 [member]|비지배지분 [member]
# 107  자본변동표        기말자본           자본 [member]|지배기업의 소유주에게 귀속되는 자본 [member]
# 108  자본변동표        기말자본  자본 [member]|지배기업의 소유주에게 귀속되는 자본 [member]|기타자본구...
# 109  자본변동표        기말자본  자본 [member]|지배기업의 소유주에게 귀속되는 자본 [member]|기타포괄손...
# 110  자본변동표        기말자본  자본 [member]|지배기업의 소유주에게 귀속되는 자본 [member]|이익잉여금...
# 111  자본변동표        기말자본  자본 [member]|지배기업의 소유주에게 귀속되는 자본 [member]|자본금 [...
# 112  자본변동표        기말자본  자본 [member]|지배기업의 소유주에게 귀속되는 자본 [member]|자본잉여금...
#
#             당기명          당기금액  전기명 전기금액 ord
# 86   제 26 기 1분기  205671999268  NaN  NaN   1
# 87   제 26 기 1분기  205671999268  NaN  NaN   1
# 88   제 26 기 1분기  -21151879846  NaN  NaN   1
# 89   제 26 기 1분기    -372462030  NaN  NaN   1
# 90   제 26 기 1분기  153806364179  NaN  NaN   1
# 91   제 26 기 1분기    5182644500  NaN  NaN   1
# 92   제 26 기 1분기   68207332465  NaN  NaN   1
# 93   제 26 기 1분기     920494020  NaN  NaN   2
# 94   제 26 기 1분기     920494020  NaN  NaN   2
# 95   제 26 기 1분기    3271994459  NaN  NaN   3
# 96   제 26 기 1분기    -133133791  NaN  NaN   3
# 97   제 26 기 1분기    3405128250  NaN  NaN   3
# 98   제 26 기 1분기    3405128250  NaN  NaN   3
# 99   제 26 기 1분기      13210628  NaN  NaN   4
# 100  제 26 기 1분기      13210628  NaN  NaN   4
# 101  제 26 기 1분기      13210628  NaN  NaN   4
# 102  제 26 기 1분기    7817204700  NaN  NaN   5
# 103  제 26 기 1분기    7817204700  NaN  NaN   5
# 104  제 26 기 1분기    7817204700  NaN  NaN   5
# 105  제 26 기 1분기  202060493675  NaN  NaN   6
# 106  제 26 기 1분기     787360229  NaN  NaN   6
# 107  제 26 기 1분기  201273133446  NaN  NaN   6
# 108  제 26 기 1분기  -21151879846  NaN  NaN   6
# 109  제 26 기 1분기    -359251402  NaN  NaN   6
# 110  제 26 기 1분기  149394287729  NaN  NaN   6
# 111  제 26 기 1분기    5182644500  NaN  NaN   6
# 112  제 26 기 1분기   68207332465  NaN  NaN   6

# %%
dart.major_shareholders_exec('안랩')

# %%
dart.major_shareholders('안랩')
# Out:
#          rcept_no    rcept_dt corp_code corp_name report_tp  \
# 0  20180814001802  2018-08-14  00298270        안랩        약식
# 1  20190211000417  2019-02-11  00298270        안랩        약식
# 2  20190503000299  2019-05-03  00298270        안랩        약식
# 3  20190809000087  2019-08-09  00298270        안랩        약식
#
#               repror    stkqy stkqy_irds stkrt stkrt_irds ctr_stkqy ctr_stkrt  \
# 0  GOETFSolutionsLLP  525,814     28,491  5.25       0.28         -         -
# 1  GOETFSolutionsLLP  401,793   -124,021  4.01      -1.24         -         -
# 2  GOETFSolutionsLLP  555,543     63,201  5.55       0.63         -         -
# 3  GOETFSolutionsLLP  446,574   -108,969  4.46      -1.09         -         -
#
#                 report_resn
# 0     - 단순투자목적으로 장내에서 주식 매수
# 1  - 투자자금 회수목적으로 장내에서 주식 매도
# 2     - 단순투자목적으로 장내에서 주식 매수
# 3  - 투자자금 회수목적으로 장내에서 주식 매도
